# %% [markdown]
# # Extração de dados da RAIS através da plataforma Base dos Dados utilizando web scrapping

# %%
# --- 1. INSTALANDO E IMPORTANDO BIBLIOTECAS NECESSÁRIAS
## Bibliotecas necessárias a serem instaladas
# !pip install basedosdados pandas
# !pip install openpyxl

## Importando bibliotecas necessárias
import pandas as pd                             
import basedosdados as bd

# --- 2. CONFIGURAÇÃO DOS PARÂMETROS ---
# Definindo  os parâmetros da consulta.
anos = [2015, 2019]
id_municipio_vca = '2933307' # Código IBGE para Vitória da Conquista

# --- 3. MONTAGEM DA CONSULTA SQL ---
# A consulta SQL foi ajustada aplicando os seguintes filtros:
# - Anos: 2015 e 2019
# - Município: Vitória da Conquista (2933307)
# - Vínculo: CLT U/PJ IND (código '10')
# - Carga Horária: 41 a 44 horas semanais (código '6')

query = f"""
SELECT
    ano,
    id_municipio,
    tipo_vinculo,
    faixa_horas_contratadas,
    quantidade_horas_contratadas,
    cbo_2002,
    grau_instrucao_apos_2005,
    subsetor_ibge,
    valor_remuneracao_media
FROM
    `basedosdados.br_me_rais.microdados_vinculos`
WHERE
    ano IN ({', '.join(map(str, anos))})
    AND id_municipio = '{id_municipio_vca}'
    AND tipo_vinculo = '10'
    AND faixa_horas_contratadas = '6'
"""

# --- 4. EXECUÇÃO DA CONSULTA E DOWNLOAD DOS DADOS ---
# Adicionando o 'billing_project_id' 
billing_project_id = "basedosdados-381718" 

print("Iniciando o download dos dados da Base dos Dados...")
print("Isso pode levar alguns minutos...")

# EXECUTANDO A CONSULTA
try:
    # A biblioteca pedirá autenticação na primeira vez que for executada.
    df = bd.read_sql(query, billing_project_id=billing_project_id)
    print("\nDownload concluído com sucesso!")

    # --- 5. SEPARAÇÃO E SALVAMENTO DOS ARQUIVOS ---
    # Separando os dados por ano e salvando em arquivos .xlsx

    # Separando o DataFrame de 2015
    df_2015 = df[df['ano'] == 2015]
    arquivo_2015 = 'rais_vca_2015.xlsx'
    df_2015.to_excel(arquivo_2015, index=False)
    print(f"Dados de 2015 salvos em: {arquivo_2015}")

    # Separando o DataFrame de 2019
    df_2019 = df[df['ano'] == 2019]
    arquivo_2019 = 'rais_vca_2019.xlsx'
    df_2019.to_excel(arquivo_2019, index=False)
    print(f"Dados de 2019 salvos em: {arquivo_2019}")
    
    print("\nProcesso finalizado!")

except Exception as e:
    print(f"\nOcorreu um erro: {e}")
    print("\nVerifique se você está logado na conta Google correta e se o projeto 'basedosdados-381718' tem o BigQuery API ativado.")
    print("Para autenticar novamente, você pode precisar apagar a pasta de credenciais da basedosdados no seu computador.")
# Out:
# Requirement already satisfied: basedosdados in c:\users\mauri\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pandas in c:\users\mauri\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: google-api-python-client<3.0,>=2.86 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (2.171.0)
# Requirement already satisfied: google-cloud-bigquery<4.0,>=3.10 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (3.34.0)
# Requirement already satisfied: google-cloud-bigquery-connection<2.0,>=1.12 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (1.18.2)
# Requirement already satisfied: google-cloud-bigquery-storage<3.0,>=2.19 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (2.32.0)
# Requirement already satisfied: google-cloud-storage<3.0,>=2.9 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (2.19.0)
# Requirement already satisfied: loguru<0.8.0,>=0.7.0 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (0.7.3)
# Requirement already satisfied: pandas-gbq>=0.19 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (0.29.1)
# Requirement already satisfied: pydata-google-auth<2.0,>=1.8 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (1.9.1)
# Requirement already satisfied: tomlkit<0.12,>=0.11 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (0.11.1)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\mauri\anaconda3\lib\site-packages (from basedosdados) (4.66.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mauri\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mauri\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mauri\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mauri\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (2.40.3)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\mauri\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (2.25.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\mauri\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (4.2.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\mauri\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (25.0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.32.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\mauri\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\mauri\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (6.31.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-cloud-storage<3.0,>=2.9->basedosdados) (1.7.1)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\mauri\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.0->basedosdados) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\mauri\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.0->basedosdados) (1.2.0)
# Requirement already satisfied: setuptools in c:\users\mauri\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (75.1.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in c:\users\mauri\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (1.4.3)
# Requirement already satisfied: pyarrow>=4.0.0 in c:\users\mauri\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (16.1.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in c:\users\mauri\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (1.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\mauri\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\mauri\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0,>=2.86->basedosdados) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\mauri\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.73.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\mauri\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.73.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mauri\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mauri\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mauri\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq>=0.19->basedosdados) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\mauri\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0,>=2.86->basedosdados) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mauri\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mauri\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mauri\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mauri\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (2025.4.26)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mauri\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mauri\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq>=0.19->basedosdados) (3.2.2)
# Requirement already satisfied: openpyxl in c:\users\mauri\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\mauri\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Iniciando o download dos dados da Base dos Dados...
# Isso pode levar alguns minutos...
# Downloading: 100%|██████████|
#
# Download concluído com sucesso!
# Dados de 2015 salvos em: rais_vca_2015.xlsx
# Dados de 2019 salvos em: rais_vca_2019.xlsx
#
# Processo finalizado!
